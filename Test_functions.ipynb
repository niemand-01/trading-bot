# %%
from trading_bot.ops import (get_state,sigmoid)
from trading_bot.utils import (get_stock_data)

# %%
fpath = "D:\Python_projects\DQN-trading-bot\data\AAPL.csv"
d = get_stock_data(fpath)

# %%
d
# Out:
# [24.171816,
#  23.913574,
#  23.773415,
#  24.1891,
#  24.294704,
#  23.988459,
#  23.96542,
#  23.596777,
#  23.033258,
#  23.317417,
#  23.066858,
#  23.195499,
#  23.279978,
#  23.33758,
#  24.031658,
#  24.208294,
#  24.8419,
#  24.749739,
#  25.240299,
#  25.254692,
#  25.28734,
#  25.635815,
#  25.73374,
#  25.941095,
#  26.550694,
#  26.43549,
#  27.19006,
#  27.241896,
#  27.623968,
#  27.736303,
#  28.062693,
#  27.951332,
#  27.538542,
#  27.58749,
#  27.239973,
#  27.121899,
#  26.749413,
#  27.738211,
#  27.762213,
#  27.765099,
#  28.230688,
#  28.354528,
#  28.659813,
#  28.813412,
#  29.021738,
#  30.21501,
#  30.527967,
#  29.711012,
#  29.810854,
#  29.713896,
#  29.517092,
#  29.648617,
#  29.572775,
#  29.551661,
#  29.303013,
#  28.894049,
#  29.201252,
#  29.698532,
#  30.028772,
#  30.553896,
#  30.444448,
#  30.587496,
#  30.343655,
#  30.530851,
#  30.398371,
#  29.570858,
#  29.475811,
#  28.95261,
#  28.847979,
#  29.609255,
#  29.446045,
#  30.082533,
# ...

# %%
sigmoid(0)
# Out:
# 0.5

# %%
1 if 1>0 else 2
# Out:
# 1

# %%
get_state(d,11,11)
# Out:
# array([[0.4650175 , 0.60245025, 0.52637649, 0.42403156, 0.4942405 ,
#         0.40886896, 0.36273362, 0.57056556, 0.43768591, 0.53211597]])
